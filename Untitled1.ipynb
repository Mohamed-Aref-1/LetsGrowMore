# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_frame = pd.read_csv('LetsGrowMore 1st Project.csv')

# %%
data_frame.head()
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 5.1                3.5                 1.4
# 2                 5.1                3.5                 1.4
# 3                 5.1                3.5                 1.4
# 4                 5.1                3.5                 1.4
#
#    petal width in cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %%
data_frame.rename(columns={"sepal length in cm": "sepal_length", "sepal width in cm": "sepal_width", "petal length in cm": "petal_length", "petal width in cm": "petal_width"}, inplace=True)
data_frame =  data_frame.copy()

# %%
data_frame
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             5.1          3.5           1.4          0.2     Iris-setosa
# 2             5.1          3.5           1.4          0.2     Iris-setosa
# 3             5.1          3.5           1.4          0.2     Iris-setosa
# 4             5.1          3.5           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
data_frame.shape
# Out:
# (149, 5)

# %%
data_frame.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.858389     3.057047      3.771812     1.203356
# std        0.815981     0.434377      1.763062     0.763740
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.400000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data_frame.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
sns.relplot(data=data_frame, x='class', y='sepal_width')
plt.show()

# %%
sns.relplot(data=data_frame, x='sepal_length', y='sepal_width', hue = 'class')

# %%
sns.relplot(
    data=data_frame, kind="line",
    x="sepal_length", y="sepal_width",
    hue="class", style="class",
)

# %%
sns.scatterplot(data=data_frame, x='sepal_length', y='sepal_width', hue='class', palette='viridis', size ='class')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.histplot(data_frame['sepal_length'], kde = True , bins = 15)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data_frame['sepal_length'], kde = True , bins = 30 , palette ='viridis')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.relplot(
    data=data_frame, kind="line",
    x="sepal_length", y="sepal_width",
    hue="class", style="class",  dashes=False, markers=True
)

# %%
sns.relplot(
    data=data_frame, kind="line",
    x="sepal_length", y="sepal_width",
    hue="class", size="class", palette="nipy_spectral_r",
)

# %%
sns.relplot(
    data=data_frame, kind="line",
    x="sepal_length", y="sepal_width",
    hue="class", size="class", palette="nipy_spectral_r",
)

# %%
sns.relplot( data = data_frame , kind = 'line' ,  x="sepal_length", y="sepal_width",  hue="class", sort = False)

# %%
data_frame
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             5.1          3.5           1.4          0.2     Iris-setosa
# 2             5.1          3.5           1.4          0.2     Iris-setosa
# 3             5.1          3.5           1.4          0.2     Iris-setosa
# 4             5.1          3.5           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
sns.relplot(data= data_frame , x ='petal_length' , y = 'petal_width', hue = 'class', kind = 'line' , sort = True, dashes=True, markers=True )

# %%
sns.barplot(x = 'class' ,  y = 'petal_width', data=data_frame , palette = 'YlGnBu')
# Out:
# <AxesSubplot:xlabel='class', ylabel='petal_width'>

# %%
sns.boxplot(x = 'class' , y = 'petal_width' , data = data_frame, hue = 'class')
# Out:
# <AxesSubplot:xlabel='class', ylabel='petal_width'>

# %%
sns.boxplot(x = 'class' , y = 'petal_length' , data = data_frame, hue = 'class')
# Out:
# <AxesSubplot:xlabel='class', ylabel='petal_length'>

# %%
sns.boxplot(x = 'class' , y = 'sepal_length' , data = data_frame, hue = 'class')
# Out:
# <AxesSubplot:xlabel='class', ylabel='sepal_length'>

# %%
sns.boxplot(x = 'class' , y = 'sepal_width' , data = data_frame, hue = 'class')
# Out:
# <AxesSubplot:xlabel='class', ylabel='sepal_width'>

# %%
sns.stripplot(x = 'class' , y = 'sepal_width' , data=data_frame , hue = 'class', palette = 'YlGnBu', dodge = True)
# Out:
# <AxesSubplot:xlabel='class', ylabel='sepal_width'>

# %%
sns.jointplot(x = 'sepal_length' ,  y = 'sepal_width', data= data_frame ,kind ='reg')

# %%
sns.jointplot(x = 'petal_length' ,  y = 'sepal_width', data= data_frame ,kind ='kde')

# %%
data_frame['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
def change_class_to_num(x):
    if x == 'Iris-setosa':
        return 0
    if x == 'Iris-versicolor':
        return 1
    if x == 'Iris-virginica':
        return 2
data_frame['class'] = data_frame['class'].apply(change_class_to_num)
data_frame
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  class
# 0             5.1          3.5           1.4          0.2      0
# 1             5.1          3.5           1.4          0.2      0
# 2             5.1          3.5           1.4          0.2      0
# 3             5.1          3.5           1.4          0.2      0
# 4             5.1          3.5           1.4          0.2      0
# ..            ...          ...           ...          ...    ...
# 144           6.7          3.0           5.2          2.3      2
# 145           6.3          2.5           5.0          1.9      2
# 146           6.5          3.0           5.2          2.0      2
# 147           6.2          3.4           5.4          2.3      2
# 148           5.9          3.0           5.1          1.8      2
#
# [149 rows x 5 columns]

# %%
sns.pairplot(data_frame.select_dtypes(['number']), hue = 'class')

# %%
data_frame.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width     class
# sepal_length      1.000000    -0.116595      0.867407     0.812948  0.778006
# sepal_width      -0.116595     1.000000     -0.434877    -0.371463 -0.430926
# petal_length      0.867407    -0.434877      1.000000     0.962661  0.948570
# petal_width       0.812948    -0.371463      0.962661     1.000000  0.956217
# class             0.778006    -0.430926      0.948570     0.956217  1.000000

# %%
sns.heatmap(data_frame.corr(), annot = True, cmap ='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
sns.clustermap(data_frame.drop('class', axis = 1))

# %%
sns.pairplot(data_frame, hue = "class", kind = 'kde', diag_kind = 'hist')

# %% [markdown]
# # Building to model

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
le = le = LabelEncoder()

# %%
data_frame['class'] = le.fit_transform = (data_frame['class'])
data_frame.head(100)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  class
# 0            5.1          3.5           1.4          0.2      0
# 1            5.1          3.5           1.4          0.2      0
# 2            5.1          3.5           1.4          0.2      0
# 3            5.1          3.5           1.4          0.2      0
# 4            5.1          3.5           1.4          0.2      0
# ..           ...          ...           ...          ...    ...
# 95           5.7          2.9           4.2          1.3      1
# 96           6.2          2.9           4.3          1.3      1
# 97           5.1          2.5           3.0          1.1      1
# 98           5.7          2.8           4.1          1.3      1
# 99           6.3          3.3           6.0          2.5      2
#
# [100 rows x 5 columns]

# %%
x = data_frame.drop(columns = 'class' , axis = 1)
y = data_frame['class']

# %%
print(f'The shape of Y is {y.shape}, and x shape is {x.shape}')
# Out:
# The shape of Y is (149,), and x shape is (149, 4)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state= 2, test_size = 0.17)

# %%
print(f'X_train shape is {x_train.shape}, and y_train shape is {y_train.shape}')
# Out:
# X_train shape is (119, 4), and y_train shape is (119,)

# %% [markdown]
# # Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score , ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix

# %%
logistic_model= LogisticRegression(max_iter=1000)

# %%
logistic_model.fit(x_train , y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_predict =logistic_model.predict(x_test)
score_lr=accuracy_score(y_test,y_predict)

# %%
def report(model):
    preds=model.predict(x_test)
    print(classification_report(preds,y_test))
    cm = confusion_matrix(y_test, preds, labels = model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = model.classes_)
    disp.plot()
#     plt.show()

# %%
print('Logistic Regression')
report(logistic_model)
print(f'Accuracy: {round(score_lr*100,2)}%')
plt.grid(False)
# Out:
# Logistic Regression
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.82      1.00      0.90         9
#            2       1.00      0.86      0.92        14
#
#     accuracy                           0.95        38
#    macro avg       0.94      0.95      0.94        38
# weighted avg       0.96      0.95      0.95        38
#
# Accuracy: 96.67%

# %%
#Accuracy of the Logistic regression :  96.67%

# %% [markdown]
# # KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KNN = KNeighborsClassifier(n_neighbors= 10)

# %%
KNN.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_prediction_knn = KNN.predict(x_test)
score_Knn = accuracy_score(y_prediction_knn, y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
print('K Nearest Neighbours Algorithm')
report(KNN)
print(f'Accuracy: {round(score_Knn*100,2)}%')
plt.grid(False)
# Out:
# K Nearest Neighbours Algorithm
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.86      0.86      0.86         7
#            2       0.89      0.89      0.89         9
#
#     accuracy                           0.92        26
#    macro avg       0.92      0.92      0.92        26
# weighted avg       0.92      0.92      0.92        26
#
# Accuracy: 92.31%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
#Accuracy of the K Nearest Neighbours :  92.31%

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decesion_tree = DecisionTreeClassifier().fit(x_train , y_train)

# %%
y_pred_dt = decesion_tree.predict(x_test)
score_Dt = accuracy_score(y_pred_dt ,  y_test)

# %%
print('Decision Tree Classifier Algorithm')
report(decesion_tree)
print(f'Accuracy: {round(score_Dt*100,2)}%')
# Out:
# Decision Tree Classifier Algorithm
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.86      1.00      0.92         6
#            2       1.00      0.90      0.95        10
#
#     accuracy                           0.96        26
#    macro avg       0.95      0.97      0.96        26
# weighted avg       0.97      0.96      0.96        26
#
# Accuracy: 96.15%

# %%
#Accuracy of Decision Tree :  96.15%

# %%
summary = {'Regression': ['Logistic Regression', 'Decision Tree', 'KNN'], 'Accuracy': [logistic_model.score(x_test, y_test), decesion_tree.score(x_test, y_test), KNN.score(x_test, y_test)]}
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
summary_nparray = np.array([['Logistic Regression', logistic_model.score(x_test,y_test)],
                          ['Decision Tree',decesion_tree.score(x_test,y_test)],
                         ['KNN',KNN.score(x_test,y_test)]])


summary_as_df = pd.DataFrame(data=data_nparray, columns=[ 'Regression', 'Accuracy'])
summary_as_df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
#             Regression            Accuracy
# 0  Logistic Regression  0.9615384615384616
# 1        Decision Tree  0.9615384615384616
# 2                  KNN  0.9230769230769231

# %%
import matplotlib.pyplot as plt
import numpy as np

x_axis = ['Logistic Regression', 'Decision Tree', 'KNN']
y_axis = [logistic_model.score(x_test, y_test), decesion_tree.score(x_test, y_test), KNN.score(x_test, y_test)]

index = np.arange(len(x_axis))
bar_width = 0.4

plt.bar(index, y_axis, color=(0.5, 0.2, 0.8), width=bar_width)

# Customizing the plot
plt.ylabel('Accuracy')
plt.xlabel('Regression')
plt.title('Accuracy Comparison')
plt.xticks(index, x_axis)
plt.ylim([0, 1])

# Adding data labels to the bars
for i, v in enumerate(y_axis):
    plt.text(i, v + 0.01, str(round(v, 2)), ha='center')

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
